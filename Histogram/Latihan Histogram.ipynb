# %% [markdown]
# Soal nomer 1

# %%
import numpy as np
import matplotlib.pyplot as plt
histo = [120, 129, 122, 121, 125, 130, 
         124, 128, 125, 123, 129, 129, 
         127, 123, 122, 128, 121, 125, 
         122, 126, 124, 127, 139, 120,
         128, 128, 123, 120, 129, 121,
         128, 127, 124, 122, 121, 126]

plt.style.use('ggplot')
plt.hist(histo, bins =100,color=['yellow'],label=['Histo'])
plt.legend()
plt.show()

# %% [markdown]
# Soal nomer 2

# %%
import numpy as np
import matplotlib.pyplot as plt
histo = [7,7,7,7,7,5,5,5,5,5,
7,7,7,6,6,6,6,5,5,5,
5,5,5,5,5,4,4,5,5,5,
3,3,3,3,4,4,4,4,5,6,
4,4,4,2,2,0,0,0,0,1,
5,5,6,7,7,7,7,6,6,7,
4,4,3,3,4,5,5,5,6,6,
7,7,7,7,7,6,7,7,7,5,
6,6,6,6,7,7,7,5,5,5,
4,4,4,5,5,5,6,6,6,6]

plt.style.use('ggplot')
plt.hist(histo, bins =100,color=['red'],label=['Histo'])
plt.legend()
plt.show()
